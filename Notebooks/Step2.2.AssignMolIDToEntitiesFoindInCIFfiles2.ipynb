# %% [markdown]
# # Assign MolID to the entities found in the CIF files (2)

# %% [markdown]
# ## What is the goal of this notebook?
#
# This is a continuation from `Assign MolID to the entities found in the CIF files (1)`.
# In this notebook we will show what happens when you assign the same name to different chains, because you want to concatenate them. For example, if you want to make all the waters or ions be in the same chain.
#
# **Note:** Make sure to run part 1 of this step in advance.

# %%
## First, import library and setup directories

# %%
from PDBClean import pdbclean_io

# %%
PROJDIR="./TIM/"

# %%
pdbclean_io.check_project(projdir=PROJDIR, action='create', level='simple_bank_sub2')

# %%
# Let's copy the same structures we selected on step 2.1 

! cp $PROJDIR/simple_bank_sub/*cif $PROJDIR/simple_bank_sub2/

# %%
pdbclean_io.check_project(projdir=PROJDIR, action='create', level='standard_MolID_bank2')

# %% [markdown]
# ### Running PDBClean_MolID_CIF.py
#
# Remember that the way to run this script in the terminal is as following:
#
# > PDBClean_MolID_CIF.py `{Input Directory}` `{Output Directory}`
#
# The input directory contains the structures that we generated in Step 1. The output directory is where the new structures will be stored.

# %% [markdown]
# ### Renaming MolID, how to choose a name?
#
# This is a personal decision. You can decide how name each entity. In part 2.1 we assigned a different MolID to each entity, as shown in the table below:
#
# | New MolID | ENTITIES |
# |---|:---|
# | A | 1:TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM: |
# | B | 1:SN-GLYCEROL-3-PHOSPHATE: |
# | C | 1:SN-GLYCEROL-1-PHOSPHATE: |
# | D,E | 2:GLYCEROL: |
# | F,G | 2:WATER: |
# | H,I | 2:TRIOSEPHOSPHATE ISOMERASE: |
# | J | 1:PHOSPHATE ION: |
# | K,L | 2:2-PHOSPHOGLYCOLIC ACID: |
#
#
# For this example, let's try assigning the same MolID to different entities:
#
# | New MolID | ENTITIES |
# |---|:---|
# | A | 1:TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM: |
# | D | 1:SN-GLYCEROL-3-PHOSPHATE: |
# | D | 1:SN-GLYCEROL-1-PHOSPHATE: |
# | D,D | 2:GLYCEROL: |
# | C,C | 2:WATER: |
# | A,B | 2:TRIOSEPHOSPHATE ISOMERASE: |
# | D | 1:PHOSPHATE ION: |
# | D,D | 2:2-PHOSPHOGLYCOLIC ACID: |

# %%
! echo '2\n5\nA\nD\nD\nD,D\nC,C\nA,B\nD\nD,D\n7\n2\nQUIT\n' | PDBClean_MolID_CIF.py $PROJDIR/simple_bank_sub2 $PROJDIR/standard_MolID_bank2
# Out:
# Reading: ./TIM//simple_bank_sub2/2y62+00.cif  (1 of 6)
# Reading: ./TIM//simple_bank_sub2/1ag1+00.cif  (2 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+04.cif  (3 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+02.cif  (4 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+03.cif  (5 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+01.cif  (6 of 6)
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
# Option Number: 1:TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM:
# 1:SN-GLYCEROL-3-PHOSPHATE:
# 1:SN-GLYCEROL-1-PHOSPHATE:
# 2:GLYCEROL:
# 2:WATER:
# 2:TRIOSEPHOSPHATE ISOMERASE:
# 1:PHOSPHATE ION:
# 2:2-PHOSPHOGLYCOLIC ACID:
# You need to accept 8 entity conversions
# You need to accept 12 total chain conversions
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
# Option Number: Enter chain IDs for each of the following MolID.
# Comma separated, no spaces
# TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM:SN-GLYCEROL-3-PHOSPHATE:SN-GLYCEROL-1-PHOSPHATE:GLYCEROL:WATER:TRIOSEPHOSPHATE ISOMERASE:PHOSPHATE ION:2-PHOSPHOGLYCOLIC ACID:Congratulations! You have successfully constructed your
#                  conversion templates. You can proceed to the next section
#                  by selection option 7 or, continue to edit your conversion
#                  template through this menu
#
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
#     7) Continue to next step of curation
# Option Number: PDBClean Concatenations Menu
#                  -------------------------------
#                  This menu appeared because you have assigned the same chain name to two (or more) entities.
#                  Note that this will concatenate the entities. So you need to either re-assign chain names,
#                  or ACCEPT concatenations.
#
#                  Note: All proposed concatenations must be accepted (by running option 4 or 5) before the curation can
#                  be completed.
#
#                  Before you do anything, we suggest to choose option 2, so you know which concatenations have not
#                  been accepted. It will also give you the proper format of the input for option 3.
#
#                  If you are sure that all the concatenations are correct. Option 5 will accept all of them. They
#                  will be printed to screen as they are being accepted.
#
#                  Select one of the following options to proceed:
#                  1) Show all conversions
#                  2) Show only unaccepted concatenations
#                  3) Search and modify destination chainIDs of proposed concatenations
#                  4) Accept proposed concatenation one by one
#                     (Repeat this step until finalizing option appears)
#                  5) Accept ALL (BE CAREFUL, make sure you agree with all concatenations)
#
# Option Number: ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-3-PHOSPHATE:B:D:1
# ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-1-PHOSPHATE:C:D:2
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:D:D:3
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:E:D:4
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:D:C:1
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:E:C:2
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:O:D:1
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:P:D:2
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:W:C:1
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:X:C:2
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:K:D:1
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:L:D:2
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:S:C:1
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:T:C:2
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:M:D:1
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:N:D:2
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:U:C:1
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:V:C:2
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:I:D:1
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:J:D:2
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:Q:C:1
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:R:C:2
# You need to accept 22 concatenations
# PDBClean Concatenations Menu
#                  -------------------------------
#                  This menu appeared because you have assigned the same chain name to two (or more) entities.
#                  Note that this will concatenate the entities. So you need to either re-assign chain names,
#                  or ACCEPT concatenations.
#
#                  Note: All proposed concatenations must be accepted (by running option 4 or 5) before the curation can
#                  be completed.
#
#                  Before you do anything, we suggest to choose option 2, so you know which concatenations have not
#                  been accepted. It will also give you the proper format of the input for option 3.
#
#                  If you are sure that all the concatenations are correct. Option 5 will accept all of them. They
#                  will be printed to screen as they are being accepted.
#
#                  Select one of the following options to proceed:
#                  1) Show all conversions
#                  2) Show only unaccepted concatenations
#                  3) Search and modify destination chainIDs of proposed concatenations
#                  4) Accept proposed concatenation one by one
#                     (Repeat this step until finalizing option appears)
#                  5) Accept ALL (BE CAREFUL, make sure you agree with all concatenations)
#
# Option Number:

# %% [markdown]
# ## A pause to explain what is going on:
#
# Notice that a new menu appears when we assign the same MolID to more than one entity. We need to either give a new MolID to the entities, or accept a concatenation. We want to guarantee that you did not assign the same MolID by mistake, so you need to approve each case one by one.
#
# In the cell above, we chose option `2) Show only unaccepted concatenations`. Let's take a look at the output:
#
# `
# ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-3-PHOSPHATE:B:D:1
# ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-1-PHOSPHATE:C:D:2
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:D:D:3
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:E:D:4
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:D:C:1
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:E:C:2
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:O:D:1
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:P:D:2
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:W:C:1
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:X:C:2
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:K:D:1
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:L:D:2
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:S:C:1
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:T:C:2
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:M:D:1
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:N:D:2
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:U:C:1
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:V:C:2
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:I:D:1
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:J:D:2
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:Q:C:1
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:R:C:2
# You need to accept 22 concatenations
# `
#
# Notice that the format is:
#
# `file name` : `entity` : `New MolID we just assigned`: `order of entity with same MolID in CIF file`
#
# To continue running the script, you will need to accept each of these concatenations. For this notebook we only show how to accept three of the proposed concatenations. We recommend doing this step on the terminal, and approve each concatenation one by one.
#
# Choosing menu `4) Accept proposed concatenation one by one` will print one of the concatenations that stills need to be approved.A new menu will appear, we need to choose option `2) Accept planned concatenation`. This will bring us back to the concatenation menu. We need to repeat this step (choose option 4, and then 2), until the finalize option appears.
#
# Even though it is beneficial to check each merge one by one, it can be very tedious (in the case of ions, users would have to approve hundreds of merges), so we also provide the option to accept all the merges automatically `5) Accept ALL`. PDBCleanV2 will still print all merges to the screen, so users can verify that everything is fine.
#
# Once all concatenations have been accepted, an option to finalize the curation will appear.

# %%
! echo "2\n5\nA\nD\nD\nD,D\nC,C\nA,B\nD\nD,D\n7\n5\n6" | PDBClean_MolID_CIF.py $PROJDIR/simple_bank_sub2 $PROJDIR/standard_MolID_bank2
# Out:
# Reading: ./TIM//simple_bank_sub2/2y62+00.cif  (1 of 6)
# Reading: ./TIM//simple_bank_sub2/1ag1+00.cif  (2 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+04.cif  (3 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+02.cif  (4 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+03.cif  (5 of 6)
# Reading: ./TIM//simple_bank_sub2/1aw1+01.cif  (6 of 6)
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
# Option Number: 1:TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM:
# 1:SN-GLYCEROL-3-PHOSPHATE:
# 1:SN-GLYCEROL-1-PHOSPHATE:
# 2:GLYCEROL:
# 2:WATER:
# 2:TRIOSEPHOSPHATE ISOMERASE:
# 1:PHOSPHATE ION:
# 2:2-PHOSPHOGLYCOLIC ACID:
# You need to accept 8 entity conversions
# You need to accept 12 total chain conversions
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
# Option Number: Enter chain IDs for each of the following MolID.
# Comma separated, no spaces
# TRIOSEPHOSPHATE ISOMERASE SYNONYM TRIOSE-PHOSPHATE ISOMERASE, TIM:SN-GLYCEROL-3-PHOSPHATE:SN-GLYCEROL-1-PHOSPHATE:GLYCEROL:WATER:TRIOSEPHOSPHATE ISOMERASE:PHOSPHATE ION:2-PHOSPHOGLYCOLIC ACID:Congratulations! You have successfully constructed your
#                  conversion templates. You can proceed to the next section
#                  by selection option 7 or, continue to edit your conversion
#                  template through this menu
#
# PDBClean MolID Conversion Build Menu
#              Select one of the following options to proceed:
#              1) Show full conversion
#              2) Show only unassigned conversions
#              3) Enter input file
#              4) Search MolID to add chain ID conversion
#              5) Go entry by entry to add chain ID conversion
#              6) Remove a chain ID conversion
#              A) Track changes (original_chain_name:new_chain:entity:file_name)
#
#     7) Continue to next step of curation
# Option Number: PDBClean Concatenations Menu
#                  -------------------------------
#                  This menu appeared because you have assigned the same chain name to two (or more) entities.
#                  Note that this will concatenate the entities. So you need to either re-assign chain names,
#                  or ACCEPT concatenations.
#
#                  Note: All proposed concatenations must be accepted (by running option 4 or 5) before the curation can
#                  be completed.
#
#                  Before you do anything, we suggest to choose option 2, so you know which concatenations have not
#                  been accepted. It will also give you the proper format of the input for option 3.
#
#                  If you are sure that all the concatenations are correct. Option 5 will accept all of them. They
#                  will be printed to screen as they are being accepted.
#
#                  Select one of the following options to proceed:
#                  1) Show all conversions
#                  2) Show only unaccepted concatenations
#                  3) Search and modify destination chainIDs of proposed concatenations
#                  4) Accept proposed concatenation one by one
#                     (Repeat this step until finalizing option appears)
#                  5) Accept ALL (BE CAREFUL, make sure you agree with all concatenations)
#
# Option Number: ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-3-PHOSPHATE:B:D:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/2y62+00.cif:SN-GLYCEROL-1-PHOSPHATE:C:D:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:D:D:3
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/2y62+00.cif:GLYCEROL:E:D:4
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:D:C:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1ag1+00.cif:WATER:E:C:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:O:D:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+04.cif:2-PHOSPHOGLYCOLIC ACID:P:D:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:W:C:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+04.cif:WATER:X:C:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:K:D:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+02.cif:2-PHOSPHOGLYCOLIC ACID:L:D:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:S:C:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+02.cif:WATER:T:C:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:M:D:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+03.cif:2-PHOSPHOGLYCOLIC ACID:N:D:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:U:C:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+03.cif:WATER:V:C:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:I:D:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+01.cif:2-PHOSPHOGLYCOLIC ACID:J:D:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:Q:C:1
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# ./TIM//simple_bank_sub2/1aw1+01.cif:WATER:R:C:2
# Select one of the following options to proceed:
#                          1) Perform new search
#                          2) Accept planned concatenation
#
# 0
# Congratulations! You have successfully constructed your
#                      conversion templates.You can proceed to the next section
#                      by selection option 6 or, continue to edit your conversion
#                      template through this menu
#
# PDBClean Concatenations Menu
#                  -------------------------------
#                  This menu appeared because you have assigned the same chain name to two (or more) entities.
#                  Note that this will concatenate the entities. So you need to either re-assign chain names,
#                  or ACCEPT concatenations.
#
#                  Note: All proposed concatenations must be accepted (by running option 4 or 5) before the curation can
#                  be completed.
#
#                  Before you do anything, we suggest to choose option 2, so you know which concatenations have not
#                  been accepted. It will also give you the proper format of the input for option 3.
#
#                  If you are sure that all the concatenations are correct. Option 5 will accept all of them. They
#                  will be printed to screen as they are being accepted.
#
#                  Select one of the following options to proceed:
#                  1) Show all conversions
#                  2) Show only unaccepted concatenations
#                  3) Search and modify destination chainIDs of proposed concatenations
#                  4) Accept proposed concatenation one by one
#                     (Repeat this step until finalizing option appears)
#                  5) Accept ALL (BE CAREFUL, make sure you agree with all concatenations)
#
#     6) Finalize Curation
# Option Number: Finalizing Curation ...
